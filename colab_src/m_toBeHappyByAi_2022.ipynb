# %% [markdown]
# # 2022 TensorFlow 勉強用

# %% [markdown]
# ## 手順(1) 機械学習用のdirをマウント

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ml_dir = "gdrive/MyDrive/mnt_g_colab/colab1/"

# %%
import pandas as pd
df_study = pd.read_csv(ml_dir + 'input_sample/ans_studyInput_hp.txt', names=['id', 'truth_val', 'ラベル（教師データ）', '入力'])
df_study
# Out:
#     id truth_val ラベル（教師データ）                                                 入力
# 0    x         T         人間                     知識だけでなく、自らの精神や心にも注意を向けることができる。
# 1    x         T         人間                                         好奇心や知識欲は旺盛
# 2    x         T         人間                      自身の関心事に対して「知ること」と「考えること」を好む性質
# 3    x         T         人間        もともと採集・狩猟生活を送り、その後農業を開始し、やがて本格的に工業も行うようになった
# 4    x         T         人間                   道具を作り利用する能力が他の生物よりも長けていることも挙げられる
# 5    x         T         人間                           人間関係の網目の中での自分の場所・位置を重んじる
# 6    x         T         人間                   道具を作り利用する能力が他の生物よりも長けていることも挙げられる
# 7    x         T         人間                                            知恵があり賢い
# 8    x         T         人間                                             苦悩する存在
# 9    x         T         人間                                           苦悩に耐える存在
# 10   x         T         人間                                             テレビをみる
# 11   x         T         人間                                             ご飯を食べる
# 12   x         T         人間                               自分が発した言動の証拠集めをして思い込む
# 13   x         T         幸福                                        心が満ち足りていること
# 14   x         T         幸福                        人間は古来、幸福になるための方法に深い関心を寄せてきた
# 15   x         T         幸福                               自分にじゃれついてくる娘がいるという幸せ
# 16   x         T         幸福                           良いパートナーと出会えたと思い幸せを感じている人
# 17   x         T         幸福                          良い仕事場や職を見つけたと思い、幸せを感じている人
# 18   x         T         幸福                                東洋的な瞑想をして、幸福を感じている人
# 19   x         T         幸福                              人間が持っている機能を存分に発揮させること
# 20   x         T         幸福                                            選択肢が増える
# 21   x         T         幸福                                        感情に煩わされないこと
# 22   x         T         幸福                                         美味しい夕食を食べる
# 23   x         T         幸福                                            幸せと思い込む
# 24   x         T         不幸                                      身内の人などに死なれること
# 25   x         T         不幸                                              仕事でミス
# 26   x         T         不幸                                              物を失くす
# 27   x         T         不幸                                         家が不安定になること
# 28   x         T         不幸                                            家族を失うこと
# 29   x         T         不幸                                           病気になったとき
# 30   x         T         不幸                                            不幸と思い込む
# 31   x         T         不幸                                              苦悩が多い
# 32   x         T         成る                                           物事ができ上がる
# 33   x         T         成る                                               実現する
# 34   x         T         成る                                   今までと違った状態・形に変わる。
# 35   x         T         成る                                    変化・移行した結果が出現する。
# 36   x         T         成る                                              幸せになる
# 37   x         T         成る                                          ものが新たに現れる
# 38   x         T         成る                                           物事ができ上がる
# 39   x         T         成る                                       ある時分・時期などに至る
# 40   x         T         成る                                     前の状態から別の状態に移る。
# 41   0         T         幸福  ラテン語で「幸福」を意味するフェリスタス 金箔入り スパークリングワイン 750ml ※お酒...
# 42   1         T         幸福  一般書「「幸福」と「人生の意味」について」教皇フランシスコのあらすじ、最新情報をKADOKA...
# 43   2         T         幸福  「君ありて幸福」の「ありて」の意味 日本語を勉強中の中国人です。ゼラニウムの花言葉を探してい...
# 44   3         T         幸福  口福と幸福。この店にとって意味は同じ！？ 《お店の外観》 外見はこじんまりとしている。 立地...
# 45   4         T         幸福  漢字の成り立ち「幸」 （象形文字） ... 訓読みのしあわせの意味は幸福、嬉しさや喜び、満足...
# 46   5         T         幸福  心のバランスを上手く取る方法を体得した人間が、幸福を維持できる訳です。 ... 他の回答者が...
# 47   6         T         人間               【煩悩の数が108もある理由2】人間を苦しめる心が原因となっている —
# 48   7         T         人間                  【煩悩の数が108もある理由2】人間を苦しめる心が原因となっている
# 49   8         T         人間                  【煩悩の数が108もある理由2】人間を苦しめる心が原因となっている
# 50   9         T         人間  煩悩の数が108もある理由2】人間を ... そのため人を苦しみで縛る煩悩と同じ意味として捉...
# 51  10         T         人間                               煩悩を捨て去るにはどうすれば良いですか？
# 52  11         T         人間  人間界のみが輪廻転生の枠から逃れられるための仏の教えを学べるとされています。 天上界は極楽と...
# 53  12         T         人間                          輪廻転生はどのくらいの人が信じているのでしょうか？
# 54  13         T         成る  [1-3]で見た様に同形でも文脈により全く別の意味になる用法がかなりあるからである。 ......
# 55  14         T         成る  [1-3]で見た様に同形でも文脈により全く別の意味になる用法がかなりあるからである。 ......
# 56  15         T         不幸  いろいろの意味で恩を受けている。人生は楽しい許りの成ではないが、僕は人間に生れてよかつたと思...
# 57  16         T         不幸  いろいろの意味で恩を受けている。人生は楽しい許りの成ではないが、僕は人間に生れてよかつたと思...
# 58  17         T         不幸  詩不束なる私が、是迄繪葉書交換に付て少し感じた事を 4 話し致しましょう、すづ第 ... た...
# 59  18         T         不幸  詩不束なる私が、是迄繪葉書交換に付て少し感じた事を 4 話し致しましょう、すづ第 ... た...

# %% [markdown]
# ## 手順(2) 保存用ディレクトリ、必要なライブラリをインストール

# %%
# 入力ファイル用のディレクトリ作成
# !mkdir text
# 必要なライブラリをインストール
# !apt-get install mecab libmecab-dev mecab-ipadic-utf8
# !pip3 install mecab-python3==0.996.5 tensorflow==2.8.2

# %%
# !pwd
# !ls -ltra
# !python3 -V
# Out:
# /content
# total 20
# drwxr-xr-x 4 root root 4096 Jun 15 13:41 .config
# drwxr-xr-x 1 root root 4096 Jun 15 13:42 sample_data
# drwxr-xr-x 1 root root 4096 Jun 18 10:09 ..
# drwx------ 6 root root 4096 Jun 18 10:11 gdrive
# drwxr-xr-x 1 root root 4096 Jun 18 10:11 .
# Python 3.7.13

# %%
# !pip freeze
# !python --version

# %%
#  !rm ans_studyInput_qa.txt
 # Colaboratoryでファイルをアップロード
 from google.colab import files
 uploaded = files.upload()
# Out:
#      <input type="file" id="files-42ae0778-a6c3-488b-b2da-c561eef79fdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42ae0778-a6c3-488b-b2da-c561eef79fdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ans_studyInput_qa.txt to ans_studyInput_qa.txt

# %% [markdown]
# ## 手順(4)  学習データ（DB）を作成

# %%
import MeCab

# tagger = MeCab.Tagger('mecabrc')
tagger = MeCab.Tagger('-d /etc/alternatives/mecab-dictionary')

def tokenize(text):
    '''MeCabで形態素解析を行う''' # --- (*3)
    result = []
    word_s = tagger.parse(text)
    # print(word_s)
    for n in word_s.split("\n"):
        if n == 'EOS' or n == '': continue
        p = n.split("\t")[1].split(",")
        h, h2, org = (p[0], p[1], p[6])
        if not (h in ['名詞', '動詞', '形容詞']): continue
        if h == '名詞' and h2 == '数': continue
        if org == '*': org = n.split("\t")[0]
        result.append(org)
    # return result
    return ' '.join(result)

# %%
import pickle
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# csvファイルを読み込む
def main():
    # ファイル一覧を読む --- (*2)　目的により変える！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
    df_study = pd.read_csv(ml_dir + 'input_sample/ans_studyInput_hp.txt', names=['id', 'truth_val', 'ans', 'que'])
    # df_study = pd.read_csv('ans_studyInput_fork.txt', names=['id', 'truth_val', 'ans', 'que'])

    labelToCode = {lbl:idx for idx, lbl in enumerate(df_study.ans.unique())}
    y = df_study.ans.apply(lambda x: labelToCode[x]).tolist()

    # tfidを計算
    df_wakati = df_study["que"].apply(lambda x: tokenize(x))
    vectorizer = TfidfVectorizer(max_df=0.9, token_pattern='(?u)\\b\\w+\\b') # tf-idfの計算 1文字でもOK
    x = vectorizer.fit_transform(df_wakati).toarray()

    # オブジェクト類（tfid等）を保存
    pickle.dump(vectorizer, open(ml_dir + 'text/tfidf_vec.pickle', 'wb'))
    pickle.dump([y, x], open(ml_dir + 'text/genre.pickle', 'wb'))
    pickle.dump(labelToCode, open(ml_dir + 'text/label_to_code.pickle', 'wb'))

    print(df_wakati)

# 実行
if __name__ == '__main__':
    main()
# Out:
# 0                              知識 自ら 精神 心 注意 向ける こと できる
# 1                                           好奇 心 知識欲 旺盛
# 2                            自身 関心 事 知る こと 考える こと 好む 性質
# 3             採集 狩猟 生活 送る その後 農業 開始 する 本格 的 工業 行う よう なる
# 4                 道具 作る 利用 する 能力 他 生物 長ける いる こと 挙げる られる
# 5                              人間 関係 網目 中 自分 場所 位置 重んじる
# 6                 道具 作る 利用 する 能力 他 生物 長ける いる こと 挙げる られる
# 7                                              知恵 ある 賢い
# 8                                              苦悩 する 存在
# 9                                             苦悩 耐える 存在
# 10                                               テレビ みる
# 11                                               ご飯 食べる
# 12                               自分 発す 言動 証拠 集め する 思い込む
# 13                                        心 満ち足りる いる こと
# 14                       人間 古来 幸福 なる ため 方法 深い 関心 寄せる くる
# 15                                自分 じゃれる つく くる 娘 いる 幸せ
# 16                         良い パートナー 出会える 思う 幸せ 感じる いる 人
# 17                         良い 仕事場 職 見つける 思う 幸せ 感じる いる 人
# 18                               東洋 的 瞑想 する 幸福 感じる いる 人
# 19                           人間 持つ いる 機能 存分 発揮 する せる こと
# 20                                              選択肢 増える
# 21                                         感情 煩わす れる こと
# 22                                          美味しい 夕食 食べる
# 23                                              幸せ 思い込む
# 24                                        身内 人 死ぬ れる こと
# 25                                                仕事 ミス
# 26                                              物 失 くすい
# 27                                          家 不安定 なる こと
# 28                                             家族 失う こと
# 29                                             病気 なる とき
# 30                                              不幸 思い込む
# 31                                                苦悩 多い
# 32                                             物事 でき上がる
# 33                                                実現 する
# 34                                        今 違う 状態 形 変わる
# 35                                    変化 移行 する 結果 出現 する
# 36                                                幸せ なる
# 37                                            もの 新た 現れる
# 38                                             物事 でき上がる
# 39                                             時分 時期 至る
# 40                                         前 状態 別 状態 移る
# 41    ラテン語 幸福 意味 する フェリスタス 金箔 入り スパークリングワイン ml 酒 購入 ...
# 42    一般 書 幸福 人生 意味 教皇 フランシスコ あらす 最新 情報 KADOKAWA 公式 ...
# 43    君 ある 幸福 ある 意味 日本語 勉強 中 中国人 ゼラニウム 花言葉 探す いる ところ...
# 44    口 福 幸福 店 意味 店 外観 外見 する いる 立地 奥まる いる ため 場所 十分 調...
# 45    漢字 成り立ち 幸 象形 文字 ... 訓読み しあわせ 意味 幸福 嬉しい さ 喜ぶ 満足...
# 46    心 バランス 上手い 取る 方法 体得 する 人間 幸福 維持 できる 訳 ... 他 回答...
# 47                      煩悩 数 ある 理由 人間 苦しめる 心 原因 なる いる —
# 48                        煩悩 数 ある 理由 人間 苦しめる 心 原因 なる いる
# 49                        煩悩 数 ある 理由 人間 苦しめる 心 原因 なる いる
# 50        煩悩 数 ある 理由 人間 ... そのため 人 苦しみ 縛る 煩悩 意味 捉える ...
# 51                                        煩悩 捨て去る する 良い
# 52    人間 界 輪廻 転生 枠 逃れる られる ため 仏 教え 学べる する れる いる 天上 界...
# 53                                     輪廻 転生 人 信じる いる の
# 54    [ - ] 見る 様 同形 文脈 別 意味 なる 用法 ある ... ( ) 発話 者 S ...
# 55    [ - ] 見る 様 同形 文脈 別 意味 なる 用法 ある ... ( ) 発話 者 S ...
# 56    意味 恩 受ける いる 人生 楽しい 許 成 ない 僕 人間 生れる 思う 皆 感謝 する ...
# 57    意味 恩 受ける いる 人生 楽しい 許 成 ない 僕 人間 生れる 思う 皆 感謝 する ...
# 58    詩 不束 私 是 繪 葉書 交換 付 感じる 事 話す 致す づ ... する 立派 てる ...
# 59    詩 不束 私 是 繪 葉書 交換 付 感じる 事 話す 致す づ ... する 立派 てる ...
# Name: que, dtype: object

# %% [markdown]
# ## 手順(5)  学習モデルを作成

# %%
import pickle
import tensorflow as tf

# 分類するラベルの数
labelToCode = pickle.load(open(ml_dir + "text/label_to_code.pickle", "rb"))
nb_classes = len(labelToCode) 

# データベースの読込
data = pickle.load(open(ml_dir + "text/genre.pickle", "rb"))
x = data[1] # TF-IDF

# 入力x[0]の要素数（TF-IDF）より入力要素数を求める
in_size = x[0].shape[0]

# MLPモデル構造を定義
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(in_size,)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(512, activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(nb_classes, activation=tf.nn.softmax))

# モデルをコンパイル
model.compile(
    loss='categorical_crossentropy',
    optimizer='rmsprop',
    metrics=['accuracy'])

input_shape = x.shape
print(input_shape)

model.summary()

# モデルを保存する
model.save(ml_dir + 'text/hw_model.h5')
print('model seved')
# Out:
# (60, 279)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 512)               143360
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_16 (Dense)            (None, 512)               262656
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_17 (Dense)            (None, 4)                 2052
#
# =================================================================
# Total params: 408,068
# Trainable params: 408,068
# Non-trainable params: 0
# _________________________________________________________________
# model seved

# %% [markdown]
# ## 手順(6)  学習（MLP）を実行

# %%
import pickle
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os


# 分類するラベルの数
labelToCode = pickle.load(open(ml_dir + "text/label_to_code.pickle", "rb"))
nb_classes = len(labelToCode) 

# データベースの読込
data = pickle.load(open(ml_dir + "text/genre.pickle", "rb"))
y = data[0] # ラベルコード
x = data[1] # TF-IDF

# ラベルデータをone-hotベクトルに直す
y = tf.keras.utils.to_categorical(y, nb_classes)
in_size = x[0].shape[0] # 入力x[0]の要素数

# 学習用とテスト用を分ける
x_train, x_test, y_train, y_test = train_test_split(
        np.array(x), np.array(y), test_size=0.2)

# モデルを読み込む
model = tf.keras.models.load_model(ml_dir + 'text/hw_model.h5')

# 既に学習済みの重みデータが存在していれば読み込む
# if os.path.exists(ml_dir + 'text/hw_weights.h5'):
#     model.load_weights(ml_dir + 'text/hw_weights.h5')

# 学習を実行
hist = model.fit(x_train, y_train,
          batch_size=20, # 1回に計算するデータ数
          epochs=300,    # 学習の繰り返し回数みたいなもの
          verbose=1,
          validation_data=(x_test, y_test))

# 評価する
score = model.evaluate(x_test, y_test, verbose=1)
print("正解率=", score[1], 'loss=', score[0])

# 重みデータを保存
model.save_weights(ml_dir + 'text/hw_weights.h5')

# 学習の様子をグラフへ描画
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/300
# 3/3 [==============================] - 1s 169ms/step - loss: 1.3832 - accuracy: 0.2917 - val_loss: 1.3350 - val_accuracy: 0.4167
# Epoch 2/300
# 3/3 [==============================] - 0s 38ms/step - loss: 1.2265 - accuracy: 0.6667 - val_loss: 1.3017 - val_accuracy: 0.4167
# Epoch 3/300
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0647 - accuracy: 0.7083 - val_loss: 1.2810 - val_accuracy: 0.4167
# Epoch 4/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.9066 - accuracy: 0.8542 - val_loss: 1.2424 - val_accuracy: 0.5833
# Epoch 5/300
# 3/3 [==============================] - 0s 46ms/step - loss: 0.6873 - accuracy: 0.9792 - val_loss: 1.1963 - val_accuracy: 0.4167
# Epoch 6/300
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5120 - accuracy: 0.9792 - val_loss: 1.1577 - val_accuracy: 0.5000
# Epoch 7/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3953 - accuracy: 0.9792 - val_loss: 1.1976 - val_accuracy: 0.5833
# Epoch 8/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2683 - accuracy: 1.0000 - val_loss: 1.1744 - val_accuracy: 0.5833
# Epoch 9/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1928 - accuracy: 1.0000 - val_loss: 1.1340 - val_accuracy: 0.5833
# Epoch 10/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1402 - accuracy: 1.0000 - val_loss: 1.1260 - val_accuracy: 0.5000
# Epoch 11/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0876 - accuracy: 1.0000 - val_loss: 1.1520 - val_accuracy: 0.5833
# Epoch 12/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 1.0988 - val_accuracy: 0.5833
# Epoch 13/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 1.1005 - val_accuracy: 0.5833
# Epoch 14/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0391 - accuracy: 1.0000 - val_loss: 1.0943 - val_accuracy: 0.5833
# Epoch 15/300
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 1.1128 - val_accuracy: 0.4167
# Epoch 16/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 1.1042 - val_accuracy: 0.5000
# Epoch 17/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 1.0534 - val_accuracy: 0.5833
# Epoch 18/300
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 1.0982 - val_accuracy: 0.5833
# Epoch 19/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.0758 - val_accuracy: 0.6667
# Epoch 20/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.0880 - val_accuracy: 0.6667
# Epoch 21/300
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.0473 - val_accuracy: 0.5000
# Epoch 22/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.0394 - val_accuracy: 0.6667
# Epoch 23/300
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.0433 - val_accuracy: 0.5000
# Epoch 24/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.0563 - val_accuracy: 0.6667
# Epoch 25/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.0743 - val_accuracy: 0.6667
# Epoch 26/300
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.0595 - val_accuracy: 0.5833
# Epoch 27/300
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0816 - val_accuracy: 0.5000
# Epoch 28/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0539 - val_accuracy: 0.6667
# Epoch 29/300
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0634 - val_accuracy: 0.6667
# Epoch 30/300
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1057 - val_accuracy: 0.5000
# Epoch 31/300
# 3/3 [==============================] - 0s 36ms/step - loss: 9.0651e-04 - accuracy: 1.0000 - val_loss: 1.1168 - val_accuracy: 0.5000
# Epoch 32/300
# 3/3 [==============================] - 0s 58ms/step - loss: 9.7704e-04 - accuracy: 1.0000 - val_loss: 1.0550 - val_accuracy: 0.4167
# Epoch 33/300
# 3/3 [==============================] - 0s 44ms/step - loss: 7.9626e-04 - accuracy: 1.0000 - val_loss: 0.9786 - val_accuracy: 0.5000
# Epoch 34/300
# 3/3 [==============================] - 0s 55ms/step - loss: 4.6650e-04 - accuracy: 1.0000 - val_loss: 0.9943 - val_accuracy: 0.5000
# Epoch 35/300
# 3/3 [==============================] - 0s 42ms/step - loss: 5.0232e-04 - accuracy: 1.0000 - val_loss: 1.0347 - val_accuracy: 0.5000
# Epoch 36/300
# 3/3 [==============================] - 0s 100ms/step - loss: 3.6916e-04 - accuracy: 1.0000 - val_loss: 1.0608 - val_accuracy: 0.5000
# Epoch 37/300
# 3/3 [==============================] - 0s 31ms/step - loss: 3.0227e-04 - accuracy: 1.0000 - val_loss: 1.0509 - val_accuracy: 0.4167
# Epoch 38/300
# 3/3 [==============================] - 0s 75ms/step - loss: 2.4810e-04 - accuracy: 1.0000 - val_loss: 1.0297 - val_accuracy: 0.5000
# Epoch 39/300
# 3/3 [==============================] - 0s 50ms/step - loss: 2.2077e-04 - accuracy: 1.0000 - val_loss: 0.9920 - val_accuracy: 0.5833
# Epoch 40/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.8726e-04 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 0.4167
# Epoch 41/300
# 3/3 [==============================] - 0s 43ms/step - loss: 1.5013e-04 - accuracy: 1.0000 - val_loss: 1.0304 - val_accuracy: 0.4167
# Epoch 42/300
# 3/3 [==============================] - 0s 62ms/step - loss: 1.2266e-04 - accuracy: 1.0000 - val_loss: 1.0613 - val_accuracy: 0.6667
# Epoch 43/300
# 3/3 [==============================] - 0s 45ms/step - loss: 1.1399e-04 - accuracy: 1.0000 - val_loss: 1.0606 - val_accuracy: 0.6667
# Epoch 44/300
# 3/3 [==============================] - 0s 62ms/step - loss: 1.2030e-04 - accuracy: 1.0000 - val_loss: 1.0137 - val_accuracy: 0.5833
# Epoch 45/300
# 3/3 [==============================] - 0s 59ms/step - loss: 6.3370e-05 - accuracy: 1.0000 - val_loss: 1.0435 - val_accuracy: 0.5000
# Epoch 46/300
# 3/3 [==============================] - 0s 59ms/step - loss: 5.1611e-05 - accuracy: 1.0000 - val_loss: 1.0469 - val_accuracy: 0.5000
# Epoch 47/300
# 3/3 [==============================] - 0s 36ms/step - loss: 5.5929e-05 - accuracy: 1.0000 - val_loss: 1.0285 - val_accuracy: 0.5000
# Epoch 48/300
# 3/3 [==============================] - 0s 73ms/step - loss: 5.2108e-05 - accuracy: 1.0000 - val_loss: 1.0413 - val_accuracy: 0.5000
# Epoch 49/300
# 3/3 [==============================] - 0s 73ms/step - loss: 3.5833e-05 - accuracy: 1.0000 - val_loss: 1.0347 - val_accuracy: 0.4167
# Epoch 50/300
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8867e-05 - accuracy: 1.0000 - val_loss: 1.0228 - val_accuracy: 0.4167
# Epoch 51/300
# 3/3 [==============================] - 0s 62ms/step - loss: 2.6113e-05 - accuracy: 1.0000 - val_loss: 1.0319 - val_accuracy: 0.4167
# Epoch 52/300
# 3/3 [==============================] - 0s 55ms/step - loss: 3.6588e-05 - accuracy: 1.0000 - val_loss: 1.0047 - val_accuracy: 0.5000
# Epoch 53/300
# 3/3 [==============================] - 0s 60ms/step - loss: 2.8083e-05 - accuracy: 1.0000 - val_loss: 1.0420 - val_accuracy: 0.4167
# Epoch 54/300
# 3/3 [==============================] - 0s 48ms/step - loss: 1.2601e-05 - accuracy: 1.0000 - val_loss: 1.0393 - val_accuracy: 0.4167
# Epoch 55/300
# 3/3 [==============================] - 0s 92ms/step - loss: 1.5060e-05 - accuracy: 1.0000 - val_loss: 1.0503 - val_accuracy: 0.4167
# Epoch 56/300
# 3/3 [==============================] - 0s 95ms/step - loss: 1.5842e-05 - accuracy: 1.0000 - val_loss: 1.0582 - val_accuracy: 0.4167
# Epoch 57/300
# 3/3 [==============================] - 0s 69ms/step - loss: 6.9190e-06 - accuracy: 1.0000 - val_loss: 1.0406 - val_accuracy: 0.4167
# Epoch 58/300
# 3/3 [==============================] - 0s 53ms/step - loss: 1.2045e-05 - accuracy: 1.0000 - val_loss: 1.0532 - val_accuracy: 0.4167
# Epoch 59/300
# 3/3 [==============================] - 0s 49ms/step - loss: 9.7150e-06 - accuracy: 1.0000 - val_loss: 1.0836 - val_accuracy: 0.4167
# Epoch 60/300
# 3/3 [==============================] - 0s 73ms/step - loss: 5.8685e-06 - accuracy: 1.0000 - val_loss: 1.0928 - val_accuracy: 0.4167
# Epoch 61/300
# 3/3 [==============================] - 0s 61ms/step - loss: 6.9014e-06 - accuracy: 1.0000 - val_loss: 1.0459 - val_accuracy: 0.4167
# Epoch 62/300
# 3/3 [==============================] - 0s 44ms/step - loss: 3.1988e-06 - accuracy: 1.0000 - val_loss: 1.0591 - val_accuracy: 0.6667
# Epoch 63/300
# 3/3 [==============================] - 0s 29ms/step - loss: 5.1508e-06 - accuracy: 1.0000 - val_loss: 1.0916 - val_accuracy: 0.5000
# Epoch 64/300
# 3/3 [==============================] - 0s 51ms/step - loss: 2.9380e-06 - accuracy: 1.0000 - val_loss: 1.0711 - val_accuracy: 0.5000
# Epoch 65/300
# 3/3 [==============================] - 0s 52ms/step - loss: 2.1905e-06 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.4167
# Epoch 66/300
# 3/3 [==============================] - 0s 34ms/step - loss: 2.9504e-06 - accuracy: 1.0000 - val_loss: 1.0568 - val_accuracy: 0.4167
# Epoch 67/300
# 3/3 [==============================] - 0s 42ms/step - loss: 2.6872e-06 - accuracy: 1.0000 - val_loss: 1.0363 - val_accuracy: 0.4167
# Epoch 68/300
# 3/3 [==============================] - 0s 34ms/step - loss: 1.8552e-06 - accuracy: 1.0000 - val_loss: 1.0536 - val_accuracy: 0.4167
# Epoch 69/300
# 3/3 [==============================] - 0s 26ms/step - loss: 2.7865e-06 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 0.4167
# Epoch 70/300
# 3/3 [==============================] - 0s 30ms/step - loss: 1.6987e-06 - accuracy: 1.0000 - val_loss: 1.0650 - val_accuracy: 0.4167
# Epoch 71/300
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3287e-06 - accuracy: 1.0000 - val_loss: 1.0421 - val_accuracy: 0.4167
# Epoch 72/300
# 3/3 [==============================] - 0s 30ms/step - loss: 8.9903e-07 - accuracy: 1.0000 - val_loss: 1.0409 - val_accuracy: 0.4167
# Epoch 73/300
# 3/3 [==============================] - 0s 26ms/step - loss: 1.5820e-06 - accuracy: 1.0000 - val_loss: 1.0349 - val_accuracy: 0.4167
# Epoch 74/300
# 3/3 [==============================] - 0s 45ms/step - loss: 8.1460e-07 - accuracy: 1.0000 - val_loss: 1.0222 - val_accuracy: 0.4167
# Epoch 75/300
# 3/3 [==============================] - 0s 37ms/step - loss: 9.3380e-07 - accuracy: 1.0000 - val_loss: 1.0628 - val_accuracy: 0.4167
# Epoch 76/300
# 3/3 [==============================] - 0s 36ms/step - loss: 8.4191e-07 - accuracy: 1.0000 - val_loss: 1.0414 - val_accuracy: 0.4167
# Epoch 77/300
# 3/3 [==============================] - 0s 31ms/step - loss: 7.1525e-07 - accuracy: 1.0000 - val_loss: 1.0689 - val_accuracy: 0.4167
# Epoch 78/300
# 3/3 [==============================] - 0s 39ms/step - loss: 4.2468e-07 - accuracy: 1.0000 - val_loss: 1.0689 - val_accuracy: 0.4167
# Epoch 79/300
# 3/3 [==============================] - 0s 59ms/step - loss: 6.9042e-07 - accuracy: 1.0000 - val_loss: 1.1443 - val_accuracy: 0.4167
# Epoch 80/300
# 3/3 [==============================] - 0s 37ms/step - loss: 3.8246e-07 - accuracy: 1.0000 - val_loss: 1.1383 - val_accuracy: 0.4167
# Epoch 81/300
# 3/3 [==============================] - 0s 33ms/step - loss: 2.3593e-07 - accuracy: 1.0000 - val_loss: 1.1186 - val_accuracy: 0.4167
# Epoch 82/300
# 3/3 [==============================] - 0s 32ms/step - loss: 3.8991e-07 - accuracy: 1.0000 - val_loss: 1.1030 - val_accuracy: 0.4167
# Epoch 83/300
# 3/3 [==============================] - 0s 26ms/step - loss: 2.6325e-07 - accuracy: 1.0000 - val_loss: 1.1073 - val_accuracy: 0.4167
# Epoch 84/300
# 3/3 [==============================] - 0s 37ms/step - loss: 2.0613e-07 - accuracy: 1.0000 - val_loss: 1.0822 - val_accuracy: 0.4167
# Epoch 85/300
# 3/3 [==============================] - 0s 41ms/step - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 1.1106 - val_accuracy: 0.4167
# Epoch 86/300
# 3/3 [==============================] - 0s 45ms/step - loss: 2.6077e-07 - accuracy: 1.0000 - val_loss: 1.0777 - val_accuracy: 0.4167
# Epoch 87/300
# 3/3 [==============================] - 0s 30ms/step - loss: 2.3345e-07 - accuracy: 1.0000 - val_loss: 1.0631 - val_accuracy: 0.4167
# Epoch 88/300
# 3/3 [==============================] - 0s 50ms/step - loss: 2.7070e-07 - accuracy: 1.0000 - val_loss: 1.0576 - val_accuracy: 0.4167
# Epoch 89/300
# 3/3 [==============================] - 0s 38ms/step - loss: 2.0117e-07 - accuracy: 1.0000 - val_loss: 1.0420 - val_accuracy: 0.4167
# Epoch 90/300
# 3/3 [==============================] - 0s 45ms/step - loss: 1.8130e-07 - accuracy: 1.0000 - val_loss: 1.0648 - val_accuracy: 0.4167
# Epoch 91/300
# 3/3 [==============================] - 0s 42ms/step - loss: 1.2418e-07 - accuracy: 1.0000 - val_loss: 1.0711 - val_accuracy: 0.4167
# Epoch 92/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3908e-07 - accuracy: 1.0000 - val_loss: 1.0484 - val_accuracy: 0.4167
# Epoch 93/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.1424e-07 - accuracy: 1.0000 - val_loss: 1.0542 - val_accuracy: 0.4167
# Epoch 94/300
# 3/3 [==============================] - 0s 57ms/step - loss: 6.4572e-08 - accuracy: 1.0000 - val_loss: 1.0462 - val_accuracy: 0.4167
# Epoch 95/300
# 3/3 [==============================] - 0s 70ms/step - loss: 9.9341e-08 - accuracy: 1.0000 - val_loss: 1.0480 - val_accuracy: 0.5000
# Epoch 96/300
# 3/3 [==============================] - 0s 81ms/step - loss: 1.1673e-07 - accuracy: 1.0000 - val_loss: 1.0755 - val_accuracy: 0.4167
# Epoch 97/300
# 3/3 [==============================] - 0s 49ms/step - loss: 9.1890e-08 - accuracy: 1.0000 - val_loss: 1.1377 - val_accuracy: 0.4167
# Epoch 98/300
# 3/3 [==============================] - 0s 44ms/step - loss: 7.6989e-08 - accuracy: 1.0000 - val_loss: 1.1243 - val_accuracy: 0.4167
# Epoch 99/300
# 3/3 [==============================] - 0s 31ms/step - loss: 7.9473e-08 - accuracy: 1.0000 - val_loss: 1.1379 - val_accuracy: 0.4167
# Epoch 100/300
# 3/3 [==============================] - 0s 39ms/step - loss: 5.4638e-08 - accuracy: 1.0000 - val_loss: 1.1191 - val_accuracy: 0.4167
# Epoch 101/300
# 3/3 [==============================] - 0s 34ms/step - loss: 1.4156e-07 - accuracy: 1.0000 - val_loss: 1.1293 - val_accuracy: 0.4167
# Epoch 102/300
# 3/3 [==============================] - 0s 52ms/step - loss: 1.0431e-07 - accuracy: 1.0000 - val_loss: 1.0942 - val_accuracy: 0.4167
# Epoch 103/300
# 3/3 [==============================] - 0s 41ms/step - loss: 8.9407e-08 - accuracy: 1.0000 - val_loss: 1.0679 - val_accuracy: 0.4167
# Epoch 104/300
# 3/3 [==============================] - 0s 52ms/step - loss: 6.4572e-08 - accuracy: 1.0000 - val_loss: 1.0617 - val_accuracy: 0.4167
# Epoch 105/300
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2914e-07 - accuracy: 1.0000 - val_loss: 1.0869 - val_accuracy: 0.4167
# Epoch 106/300
# 3/3 [==============================] - 0s 30ms/step - loss: 7.9473e-08 - accuracy: 1.0000 - val_loss: 1.0531 - val_accuracy: 0.4167
# Epoch 107/300
# 3/3 [==============================] - 0s 40ms/step - loss: 4.9671e-08 - accuracy: 1.0000 - val_loss: 1.0611 - val_accuracy: 0.4167
# Epoch 108/300
# 3/3 [==============================] - 0s 33ms/step - loss: 3.2286e-08 - accuracy: 1.0000 - val_loss: 1.0546 - val_accuracy: 0.4167
# Epoch 109/300
# 3/3 [==============================] - 0s 31ms/step - loss: 8.1956e-08 - accuracy: 1.0000 - val_loss: 1.0495 - val_accuracy: 0.4167
# Epoch 110/300
# 3/3 [==============================] - 0s 34ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 1.0534 - val_accuracy: 0.4167
# Epoch 111/300
# 3/3 [==============================] - 0s 60ms/step - loss: 2.2352e-08 - accuracy: 1.0000 - val_loss: 1.0436 - val_accuracy: 0.4167
# Epoch 112/300
# 3/3 [==============================] - 0s 33ms/step - loss: 4.9671e-08 - accuracy: 1.0000 - val_loss: 1.0290 - val_accuracy: 0.4167
# Epoch 113/300
# 3/3 [==============================] - 0s 34ms/step - loss: 2.2352e-08 - accuracy: 1.0000 - val_loss: 1.0283 - val_accuracy: 0.4167
# Epoch 114/300
# 3/3 [==============================] - 0s 43ms/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 1.0368 - val_accuracy: 0.4167
# Epoch 115/300
# 3/3 [==============================] - 0s 32ms/step - loss: 4.7187e-08 - accuracy: 1.0000 - val_loss: 1.0390 - val_accuracy: 0.4167
# Epoch 116/300
# 3/3 [==============================] - 0s 35ms/step - loss: 2.0365e-07 - accuracy: 1.0000 - val_loss: 1.1506 - val_accuracy: 0.4167
# Epoch 117/300
# 3/3 [==============================] - 0s 65ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.1460 - val_accuracy: 0.4167
# Epoch 118/300
# 3/3 [==============================] - 0s 65ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.1340 - val_accuracy: 0.4167
# Epoch 119/300
# 3/3 [==============================] - 0s 46ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.1380 - val_accuracy: 0.4167
# Epoch 120/300
# 3/3 [==============================] - 0s 51ms/step - loss: 2.4835e-08 - accuracy: 1.0000 - val_loss: 1.1135 - val_accuracy: 0.4167
# Epoch 121/300
# 3/3 [==============================] - 0s 36ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.1152 - val_accuracy: 0.4167
# Epoch 122/300
# 3/3 [==============================] - 0s 30ms/step - loss: 6.4572e-08 - accuracy: 1.0000 - val_loss: 1.1112 - val_accuracy: 0.4167
# Epoch 123/300
# 3/3 [==============================] - 0s 35ms/step - loss: 4.2220e-08 - accuracy: 1.0000 - val_loss: 1.1013 - val_accuracy: 0.4167
# Epoch 124/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.2352e-08 - accuracy: 1.0000 - val_loss: 1.0983 - val_accuracy: 0.4167
# Epoch 125/300
# 3/3 [==============================] - 0s 39ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 1.0824 - val_accuracy: 0.4167
# Epoch 126/300
# 3/3 [==============================] - 0s 40ms/step - loss: 2.4835e-08 - accuracy: 1.0000 - val_loss: 1.0897 - val_accuracy: 0.4167
# Epoch 127/300
# 3/3 [==============================] - 0s 73ms/step - loss: 2.7319e-08 - accuracy: 1.0000 - val_loss: 1.1012 - val_accuracy: 0.4167
# Epoch 128/300
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.0915 - val_accuracy: 0.4167
# Epoch 129/300
# 3/3 [==============================] - 0s 92ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0857 - val_accuracy: 0.4167
# Epoch 130/300
# 3/3 [==============================] - 0s 67ms/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 1.0880 - val_accuracy: 0.4167
# Epoch 131/300
# 3/3 [==============================] - 0s 54ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0882 - val_accuracy: 0.4167
# Epoch 132/300
# 3/3 [==============================] - 0s 45ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0803 - val_accuracy: 0.4167
# Epoch 133/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.0918 - val_accuracy: 0.4167
# Epoch 134/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.2352e-08 - accuracy: 1.0000 - val_loss: 1.0795 - val_accuracy: 0.4167
# Epoch 135/300
# 3/3 [==============================] - 0s 32ms/step - loss: 2.9802e-08 - accuracy: 1.0000 - val_loss: 1.0616 - val_accuracy: 0.5000
# Epoch 136/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.0652 - val_accuracy: 0.4167
# Epoch 137/300
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0710 - val_accuracy: 0.4167
# Epoch 138/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0738 - val_accuracy: 0.4167
# Epoch 139/300
# 3/3 [==============================] - 0s 30ms/step - loss: 3.4769e-08 - accuracy: 1.0000 - val_loss: 1.0669 - val_accuracy: 0.4167
# Epoch 140/300
# 3/3 [==============================] - 0s 28ms/step - loss: 2.4835e-08 - accuracy: 1.0000 - val_loss: 1.0590 - val_accuracy: 0.4167
# Epoch 141/300
# 3/3 [==============================] - 0s 28ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.0648 - val_accuracy: 0.4167
# Epoch 142/300
# 3/3 [==============================] - 0s 37ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.0652 - val_accuracy: 0.4167
# Epoch 143/300
# 3/3 [==============================] - 0s 37ms/step - loss: 3.7253e-08 - accuracy: 1.0000 - val_loss: 1.0816 - val_accuracy: 0.4167
# Epoch 144/300
# 3/3 [==============================] - 0s 36ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0874 - val_accuracy: 0.4167
# Epoch 145/300
# 3/3 [==============================] - 0s 32ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0898 - val_accuracy: 0.4167
# Epoch 146/300
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0748 - val_accuracy: 0.4167
# Epoch 147/300
# 3/3 [==============================] - 0s 34ms/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 1.0548 - val_accuracy: 0.4167
# Epoch 148/300
# 3/3 [==============================] - 0s 43ms/step - loss: 2.7319e-08 - accuracy: 1.0000 - val_loss: 1.0581 - val_accuracy: 0.4167
# Epoch 149/300
# 3/3 [==============================] - 0s 36ms/step - loss: 3.4769e-08 - accuracy: 1.0000 - val_loss: 1.0543 - val_accuracy: 0.4167
# Epoch 150/300
# 3/3 [==============================] - 0s 36ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0694 - val_accuracy: 0.4167
# Epoch 151/300
# 3/3 [==============================] - 0s 37ms/step - loss: 4.9671e-08 - accuracy: 1.0000 - val_loss: 1.0658 - val_accuracy: 0.4167
# Epoch 152/300
# 3/3 [==============================] - 0s 35ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0589 - val_accuracy: 0.4167
# Epoch 153/300
# 3/3 [==============================] - 0s 33ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0597 - val_accuracy: 0.4167
# Epoch 154/300
# 3/3 [==============================] - 0s 48ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0622 - val_accuracy: 0.4167
# Epoch 155/300
# 3/3 [==============================] - 0s 34ms/step - loss: 2.2352e-08 - accuracy: 1.0000 - val_loss: 1.0675 - val_accuracy: 0.4167
# Epoch 156/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.0751 - val_accuracy: 0.4167
# Epoch 157/300
# 3/3 [==============================] - 0s 45ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0742 - val_accuracy: 0.4167
# Epoch 158/300
# 3/3 [==============================] - 0s 58ms/step - loss: 2.9802e-08 - accuracy: 1.0000 - val_loss: 1.0651 - val_accuracy: 0.4167
# Epoch 159/300
# 3/3 [==============================] - 0s 34ms/step - loss: 3.4769e-08 - accuracy: 1.0000 - val_loss: 1.0876 - val_accuracy: 0.4167
# Epoch 160/300
# 3/3 [==============================] - 0s 30ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0871 - val_accuracy: 0.4167
# Epoch 161/300
# 3/3 [==============================] - 0s 38ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0898 - val_accuracy: 0.4167
# Epoch 162/300
# 3/3 [==============================] - 0s 67ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0868 - val_accuracy: 0.4167
# Epoch 163/300
# 3/3 [==============================] - 0s 50ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.0813 - val_accuracy: 0.4167
# Epoch 164/300
# 3/3 [==============================] - 0s 27ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0857 - val_accuracy: 0.4167
# Epoch 165/300
# 3/3 [==============================] - 0s 40ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0890 - val_accuracy: 0.4167
# Epoch 166/300
# 3/3 [==============================] - 0s 58ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.0961 - val_accuracy: 0.4167
# Epoch 167/300
# 3/3 [==============================] - 0s 50ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.4167
# Epoch 168/300
# 3/3 [==============================] - 0s 39ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0945 - val_accuracy: 0.4167
# Epoch 169/300
# 3/3 [==============================] - 0s 38ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0861 - val_accuracy: 0.4167
# Epoch 170/300
# 3/3 [==============================] - 0s 30ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0842 - val_accuracy: 0.4167
# Epoch 171/300
# 3/3 [==============================] - 0s 29ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0836 - val_accuracy: 0.4167
# Epoch 172/300
# 3/3 [==============================] - 0s 32ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0834 - val_accuracy: 0.4167
# Epoch 173/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0696 - val_accuracy: 0.4167
# Epoch 174/300
# 3/3 [==============================] - 0s 39ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0747 - val_accuracy: 0.4167
# Epoch 175/300
# 3/3 [==============================] - 0s 49ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0692 - val_accuracy: 0.4167
# Epoch 176/300
# 3/3 [==============================] - 0s 37ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0684 - val_accuracy: 0.4167
# Epoch 177/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0707 - val_accuracy: 0.4167
# Epoch 178/300
# 3/3 [==============================] - 0s 48ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0704 - val_accuracy: 0.4167
# Epoch 179/300
# 3/3 [==============================] - 0s 51ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0631 - val_accuracy: 0.4167
# Epoch 180/300
# 3/3 [==============================] - 0s 28ms/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 1.0533 - val_accuracy: 0.4167
# Epoch 181/300
# 3/3 [==============================] - 0s 57ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0551 - val_accuracy: 0.4167
# Epoch 182/300
# 3/3 [==============================] - 0s 56ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0620 - val_accuracy: 0.4167
# Epoch 183/300
# 3/3 [==============================] - 0s 38ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0677 - val_accuracy: 0.4167
# Epoch 184/300
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0703 - val_accuracy: 0.4167
# Epoch 185/300
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0843 - val_accuracy: 0.4167
# Epoch 186/300
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.0816 - val_accuracy: 0.4167
# Epoch 187/300
# 3/3 [==============================] - 0s 28ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.0806 - val_accuracy: 0.4167
# Epoch 188/300
# 3/3 [==============================] - 0s 43ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0780 - val_accuracy: 0.4167
# Epoch 189/300
# 3/3 [==============================] - 0s 31ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.0620 - val_accuracy: 0.5000
# Epoch 190/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 1.0724 - val_accuracy: 0.5000
# Epoch 191/300
# 3/3 [==============================] - 0s 48ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0716 - val_accuracy: 0.5000
# Epoch 192/300
# 3/3 [==============================] - 0s 38ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0599 - val_accuracy: 0.5000
# Epoch 193/300
# 3/3 [==============================] - 0s 54ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0789 - val_accuracy: 0.5000
# Epoch 194/300
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0786 - val_accuracy: 0.4167
# Epoch 195/300
# 3/3 [==============================] - 0s 30ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0742 - val_accuracy: 0.5000
# Epoch 196/300
# 3/3 [==============================] - 0s 70ms/step - loss: 3.9736e-08 - accuracy: 1.0000 - val_loss: 1.0637 - val_accuracy: 0.4167
# Epoch 197/300
# 3/3 [==============================] - 0s 42ms/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 1.1057 - val_accuracy: 0.4167
# Epoch 198/300
# 3/3 [==============================] - 0s 42ms/step - loss: 2.4835e-08 - accuracy: 1.0000 - val_loss: 1.0926 - val_accuracy: 0.4167
# Epoch 199/300
# 3/3 [==============================] - 0s 36ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0860 - val_accuracy: 0.4167
# Epoch 200/300
# 3/3 [==============================] - 0s 33ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0853 - val_accuracy: 0.4167
# Epoch 201/300
# 3/3 [==============================] - 0s 25ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0905 - val_accuracy: 0.4167
# Epoch 202/300
# 3/3 [==============================] - 0s 28ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0925 - val_accuracy: 0.4167
# Epoch 203/300
# 3/3 [==============================] - 0s 32ms/step - loss: 2.9802e-08 - accuracy: 1.0000 - val_loss: 1.0811 - val_accuracy: 0.4167
# Epoch 204/300
# 3/3 [==============================] - 0s 41ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0830 - val_accuracy: 0.4167
# Epoch 205/300
# 3/3 [==============================] - 0s 30ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0852 - val_accuracy: 0.4167
# Epoch 206/300
# 3/3 [==============================] - 0s 27ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0914 - val_accuracy: 0.4167
# Epoch 207/300
# 3/3 [==============================] - 0s 31ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0869 - val_accuracy: 0.5000
# Epoch 208/300
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0876 - val_accuracy: 0.5000
# Epoch 209/300
# 3/3 [==============================] - 0s 42ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0906 - val_accuracy: 0.5000
# Epoch 210/300
# 3/3 [==============================] - 0s 34ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0955 - val_accuracy: 0.5000
# Epoch 211/300
# 3/3 [==============================] - 0s 28ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0885 - val_accuracy: 0.5000
# Epoch 212/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.5000
# Epoch 213/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.7385e-08 - accuracy: 1.0000 - val_loss: 1.0835 - val_accuracy: 0.5000
# Epoch 214/300
# 3/3 [==============================] - 0s 32ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0693 - val_accuracy: 0.5000
# Epoch 215/300
# 3/3 [==============================] - 0s 32ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0723 - val_accuracy: 0.4167
# Epoch 216/300
# 3/3 [==============================] - 0s 31ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0688 - val_accuracy: 0.4167
# Epoch 217/300
# 3/3 [==============================] - 0s 30ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0684 - val_accuracy: 0.4167
# Epoch 218/300
# 3/3 [==============================] - 0s 55ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0662 - val_accuracy: 0.4167
# Epoch 219/300
# 3/3 [==============================] - 0s 72ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0704 - val_accuracy: 0.4167
# Epoch 220/300
# 3/3 [==============================] - 0s 70ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0732 - val_accuracy: 0.4167
# Epoch 221/300
# 3/3 [==============================] - 0s 73ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0788 - val_accuracy: 0.4167
# Epoch 222/300
# 3/3 [==============================] - 0s 45ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0800 - val_accuracy: 0.4167
# Epoch 223/300
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0785 - val_accuracy: 0.4167
# Epoch 224/300
# 3/3 [==============================] - 0s 59ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0789 - val_accuracy: 0.4167
# Epoch 225/300
# 3/3 [==============================] - 0s 43ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0804 - val_accuracy: 0.4167
# Epoch 226/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0886 - val_accuracy: 0.4167
# Epoch 227/300
# 3/3 [==============================] - 0s 26ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0916 - val_accuracy: 0.4167
# Epoch 228/300
# 3/3 [==============================] - 0s 34ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0894 - val_accuracy: 0.4167
# Epoch 229/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0903 - val_accuracy: 0.4167
# Epoch 230/300
# 3/3 [==============================] - 0s 50ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0798 - val_accuracy: 0.4167
# Epoch 231/300
# 3/3 [==============================] - 0s 30ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0813 - val_accuracy: 0.4167
# Epoch 232/300
# 3/3 [==============================] - 0s 29ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0921 - val_accuracy: 0.4167
# Epoch 233/300
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0923 - val_accuracy: 0.4167
# Epoch 234/300
# 3/3 [==============================] - 0s 32ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0946 - val_accuracy: 0.4167
# Epoch 235/300
# 3/3 [==============================] - 0s 32ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0927 - val_accuracy: 0.4167
# Epoch 236/300
# 3/3 [==============================] - 0s 90ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0910 - val_accuracy: 0.4167
# Epoch 237/300
# 3/3 [==============================] - 0s 72ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0678 - val_accuracy: 0.4167
# Epoch 238/300
# 3/3 [==============================] - 0s 30ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.4167
# Epoch 239/300
# 3/3 [==============================] - 0s 43ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0687 - val_accuracy: 0.4167
# Epoch 240/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0681 - val_accuracy: 0.4167
# Epoch 241/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0715 - val_accuracy: 0.4167
# Epoch 242/300
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0730 - val_accuracy: 0.4167
# Epoch 243/300
# 3/3 [==============================] - 0s 40ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0645 - val_accuracy: 0.4167
# Epoch 244/300
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.0550 - val_accuracy: 0.4167
# Epoch 245/300
# 3/3 [==============================] - 0s 34ms/step - loss: 3.4769e-08 - accuracy: 1.0000 - val_loss: 1.0799 - val_accuracy: 0.4167
# Epoch 246/300
# 3/3 [==============================] - 0s 56ms/step - loss: 9.9341e-09 - accuracy: 1.0000 - val_loss: 1.0872 - val_accuracy: 0.4167
# Epoch 247/300
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0861 - val_accuracy: 0.4167
# Epoch 248/300
# 3/3 [==============================] - 0s 30ms/step - loss: 2.4835e-08 - accuracy: 1.0000 - val_loss: 1.0934 - val_accuracy: 0.5000
# Epoch 249/300
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0929 - val_accuracy: 0.5000
# Epoch 250/300
# 3/3 [==============================] - 0s 30ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.0760 - val_accuracy: 0.5000
# Epoch 251/300
# 3/3 [==============================] - 0s 34ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.0756 - val_accuracy: 0.5000
# Epoch 252/300
# 3/3 [==============================] - 0s 58ms/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 1.1094 - val_accuracy: 0.5000
# Epoch 253/300
# 3/3 [==============================] - 0s 44ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1033 - val_accuracy: 0.5000
# Epoch 254/300
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1025 - val_accuracy: 0.4167
# Epoch 255/300
# 3/3 [==============================] - 0s 32ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.1085 - val_accuracy: 0.4167
# Epoch 256/300
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 1.1094 - val_accuracy: 0.4167
# Epoch 257/300
# 3/3 [==============================] - 0s 33ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.1158 - val_accuracy: 0.4167
# Epoch 258/300
# 3/3 [==============================] - 0s 27ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1143 - val_accuracy: 0.4167
# Epoch 259/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1167 - val_accuracy: 0.4167
# Epoch 260/300
# 3/3 [==============================] - 0s 33ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1192 - val_accuracy: 0.4167
# Epoch 261/300
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.1286 - val_accuracy: 0.4167
# Epoch 262/300
# 3/3 [==============================] - 0s 28ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.1291 - val_accuracy: 0.5000
# Epoch 263/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1277 - val_accuracy: 0.5000
# Epoch 264/300
# 3/3 [==============================] - 0s 40ms/step - loss: 2.7319e-08 - accuracy: 1.0000 - val_loss: 1.1300 - val_accuracy: 0.4167
# Epoch 265/300
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1311 - val_accuracy: 0.4167
# Epoch 266/300
# 3/3 [==============================] - 0s 46ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.1319 - val_accuracy: 0.4167
# Epoch 267/300
# 3/3 [==============================] - 0s 41ms/step - loss: 1.2418e-08 - accuracy: 1.0000 - val_loss: 1.1212 - val_accuracy: 0.4167
# Epoch 268/300
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1164 - val_accuracy: 0.4167
# Epoch 269/300
# 3/3 [==============================] - 0s 39ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1112 - val_accuracy: 0.4167
# Epoch 270/300
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1125 - val_accuracy: 0.4167
# Epoch 271/300
# 3/3 [==============================] - 0s 34ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1104 - val_accuracy: 0.4167
# Epoch 272/300
# 3/3 [==============================] - 0s 48ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1073 - val_accuracy: 0.4167
# Epoch 273/300
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1071 - val_accuracy: 0.4167
# Epoch 274/300
# 3/3 [==============================] - 0s 29ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1044 - val_accuracy: 0.4167
# Epoch 275/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1041 - val_accuracy: 0.4167
# Epoch 276/300
# 3/3 [==============================] - 0s 85ms/step - loss: 7.4506e-09 - accuracy: 1.0000 - val_loss: 1.1065 - val_accuracy: 0.4167
# Epoch 277/300
# 3/3 [==============================] - 0s 54ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1083 - val_accuracy: 0.4167
# Epoch 278/300
# 3/3 [==============================] - 0s 30ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.1077 - val_accuracy: 0.4167
# Epoch 279/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1058 - val_accuracy: 0.4167
# Epoch 280/300
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1066 - val_accuracy: 0.4167
# Epoch 281/300
# 3/3 [==============================] - 0s 28ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1043 - val_accuracy: 0.4167
# Epoch 282/300
# 3/3 [==============================] - 0s 28ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1017 - val_accuracy: 0.4167
# Epoch 283/300
# 3/3 [==============================] - 0s 37ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0985 - val_accuracy: 0.4167
# Epoch 284/300
# 3/3 [==============================] - 0s 48ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0930 - val_accuracy: 0.4167
# Epoch 285/300
# 3/3 [==============================] - 0s 31ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0986 - val_accuracy: 0.4167
# Epoch 286/300
# 3/3 [==============================] - 0s 28ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0983 - val_accuracy: 0.4167
# Epoch 287/300
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0980 - val_accuracy: 0.4167
# Epoch 288/300
# 3/3 [==============================] - 0s 30ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0881 - val_accuracy: 0.4167
# Epoch 289/300
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0883 - val_accuracy: 0.4167
# Epoch 290/300
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0871 - val_accuracy: 0.4167
# Epoch 291/300
# 3/3 [==============================] - 0s 61ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0992 - val_accuracy: 0.4167
# Epoch 292/300
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.0986 - val_accuracy: 0.4167
# Epoch 293/300
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.0985 - val_accuracy: 0.4167
# Epoch 294/300
# 3/3 [==============================] - 0s 21ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.0965 - val_accuracy: 0.4167
# Epoch 295/300
# 3/3 [==============================] - 0s 20ms/step - loss: 4.9671e-09 - accuracy: 1.0000 - val_loss: 1.1231 - val_accuracy: 0.4167
# Epoch 296/300
# 3/3 [==============================] - 0s 18ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1178 - val_accuracy: 0.4167
# Epoch 297/300
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1176 - val_accuracy: 0.4167
# Epoch 298/300
# 3/3 [==============================] - 0s 19ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1197 - val_accuracy: 0.4167
# Epoch 299/300
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4835e-09 - accuracy: 1.0000 - val_loss: 1.1204 - val_accuracy: 0.4167
# Epoch 300/300
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1200 - val_accuracy: 0.4167
# 1/1 [==============================] - 0s 19ms/step - loss: 1.1200 - accuracy: 0.4167
# 正解率= 0.4166666567325592 loss= 1.1199802160263062

# %% [markdown]
# ## 手順(7)  学習（MLP）モデルを実行して、判定

# %%
import pickle
import tensorflow as tf


def inverse_dict(d):
    return {v:k for k,v in d.items()}

# モデルを読み込む
model = tf.keras.models.load_model(ml_dir + 'text/hw_model.h5')
# 学習済みの重みデータを読み込む
model.load_weights(ml_dir + 'text/hw_weights.h5')
# tfidオブジェクトをファイルよりロードする
vectorizer_loaded = pickle.load(open(ml_dir + "text/tfidf_vec.pickle", "rb"))
# ラベルの定義
labelToCode = pickle.load(open(ml_dir + "text/label_to_code.pickle", "rb"))
label_dic = inverse_dict(labelToCode)

# テキストを指定して判定
def getMusicName(text):
    # TF-IDFのベクトルに変換 
    data = vectorizer_loaded.transform([tokenize(text)]).toarray()
    # MLPで予測
    pre = model.predict(data)[0]
    sortIndexDesc = pre.argsort()[::-1];
    for no, ind in enumerate(sortIndexDesc, 1):
        print(f"{no}番目の答え: {label_dic[ind]}({pre[ind]:.4f})")
        if no == 5: break

if __name__ == '__main__':
    requestParam = """
    知識をたくさん付けて選択肢を増やす
    """
    getMusicName(requestParam)
# Out:
# 1番目の答え: 幸福(0.9469)
# 2番目の答え: 人間(0.0441)
# 3番目の答え: 不幸(0.0053)
# 4番目の答え: 成る(0.0037)

# %%
getMusicName(
    """
    苦悩,耐える,言動
    """
)
# Out:
# 1番目の答え: 人間(1.0000)
# 2番目の答え: 不幸(0.0000)
# 3番目の答え: 成る(0.0000)
# 4番目の答え: 幸福(0.0000)

# %%
import pickle
import tensorflow as tf
import pandas as pd


def inverse_dict(d):
    return {v:k for k,v in d.items()}

# モデルを読み込む
model = tf.keras.models.load_model(ml_dir + 'text/hw_model.h5')
# 学習済みの重みデータを読み込む
model.load_weights(ml_dir + 'text/hw_weights.h5')
# tfidオブジェクトをファイルよりロードする
vectorizer_loaded = pickle.load(open(ml_dir + "text/tfidf_vec.pickle", "rb"))
# ラベルの定義
labelToCode = pickle.load(open(ml_dir + "text/label_to_code.pickle", "rb"))
label_dic = inverse_dict(labelToCode)

# テキストを指定して判定
def predCatego(text):
    # TF-IDFのベクトルに変換 
    data = vectorizer_loaded.transform([tokenize(text)]).toarray()
    # MLPで予測
    pre = model.predict(data)[0]
    sortIndexDesc = pre.argsort()[::-1];
    catList = []
    catDic = {}
    for no, ind in enumerate(sortIndexDesc, 1):
        catDic[label_dic[ind]] = pre[ind]
        if no == 4: break

    return catDic

def showPred(text):
    data = vectorizer_loaded.transform([tokenize(text)]).toarray()
    pre = model.predict(data)[0]
    sortIndexDesc = pre.argsort()[::-1];
    for no, ind in enumerate(sortIndexDesc, 1):
        print(f"{no}番目の答え: {label_dic[ind]}({pre[ind]:.4f})")
        if no == 7: break

def isTrgText(text):
    trgCatList = ["人間", "幸福", "成る"]
    untiTrgCatList = ["不幸"]
    predDic = predCatego(text);

    return isInTrg(text, trgCatList, untiTrgCatList, predDic)

def isInTrg(text, trgCatList, untiTrgCatList, predDic):
    thVal = 0.3  #閾値
    for trg in trgCatList:
        # print(predDic)
        if trg not in predDic: return False
        if predDic[trg] < thVal: return False

    for uTrg in untiTrgCatList:
        if predDic[uTrg] > 0.1 : return False
    
    return True

if __name__ == '__main__':
    requestParam = """
    知識をたくさん付けて選択肢を増やす
    """
    predCatego(requestParam)

# %%
isTrgText(
    """
    苦しみに耐え、知恵をしぼり、おいしいものを食べ、幸せと発する
    """
)
# Out:
# False

# %%
import pandas as pd
import itertools


limit_cnt = 20000;
act_list = ['苦悩', '耐える', '発する', '知恵', '知ること', '好奇心', '食べる', '選択肢', '増える', 'テレビ', '美味しい'
 , '飛行機', '実現する', '良い', 'パートナー', '思い', '込み',  '道具', '作り', '瞑想', '存在', '採集', '狩猟', 'する', '朝ご飯', '幸せ'
 , '睡眠', '役立つ', '人', '言動']

cnt = 1
for wc in range(3, 7):
    comb_list = list(itertools.combinations(act_list, wc))
    for comb in comb_list:
        text = ','.join(comb)
        print(f"\r計算回数: {cnt}", end='')
        # print(f"文章: {text}")
        if isTrgText(text):
            print(f"\n該当文章: {text}")
            showPred(text)
        cnt += 1
        if cnt > limit_cnt: break
    else:
        continue
    break
# Out:
# 計算回数: 1741
# 該当文章: 知ること,する,幸せ
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 10909
# 該当文章: 耐える,採集,狩猟,幸せ
# 1番目の答え: 人間(0.3633)
# 2番目の答え: 成る(0.3224)
# 3番目の答え: 幸福(0.3142)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 10973
# 該当文章: 耐える,朝ご飯,幸せ,人
# 1番目の答え: 幸福(0.3833)
# 2番目の答え: 成る(0.3088)
# 3番目の答え: 人間(0.3073)
# 4番目の答え: 不幸(0.0006)
# 計算回数: 11596
# 該当文章: 発する,知ること,する,幸せ
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 17980
# 該当文章: 知ること,飛行機,する,幸せ
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 18432
# 該当文章: 知ること,思い,する,幸せ
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 18510
# 該当文章: 知ること,込み,する,幸せ
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 18631
# 該当文章: 知ること,作り,する,幸せ
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 18786
# 該当文章: 知ること,する,幸せ,睡眠
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 18787
# 該当文章: 知ること,する,幸せ,役立つ
# 1番目の答え: 成る(0.3474)
# 2番目の答え: 幸福(0.3397)
# 3番目の答え: 人間(0.3128)
# 4番目の答え: 不幸(0.0001)
# 計算回数: 20000

# %% [markdown]
# ## 手順(8)  デプロイに必要な学習済みデータをダウンロード

# %%
! zip -r res /content/gdrive/MyDrive/mnt_g_colab/text/
from google.colab import files
files.download('res.zip')
# Out:
# updating: text/ (stored 0%)
# updating: text/genre.pickle (deflated 97%)
# updating: text/genre-model.hdf5 (deflated 9%)
# updating: text/genre-tdidf.dic (deflated 41%)
# updating: text/label_to_code.pickle (deflated 64%)

# %% [markdown]
# ## その他 ツール

# %%
import requests as web
import bs4
import csv
import time
import re

# 検索数
limit_cnt_per_key = 20
regPtn = '[亜-熙ぁ-んァ-ヶ]{10,}'  # 日本語のみ取得

# これがないと説明文とれない
user_agent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6)" \
     "AppleWebKit/537.36 (KHTML, like Gecko)" \
     "Chrome/101.0.4324.109"

with open(ml_dir + 'g_output.csv','w',newline='',encoding='utf8') as outcsv:
    csvwriter = csv.writer(outcsv, 
                    delimiter=',',  # 区切り文字はカンマ
                    quotechar='"',  # 囲い文字はダブルクォーテーション
                    quoting=csv.QUOTE_NONNUMERIC)
    csvwriter.writerow(['No','判定','曲名','説明'])
    cntMusic = 0
    key_list = [["幸福"],  ["人間"], ["成る"], ["不幸"]]

    add_str = "とは 定義 意味 類語 辞書"
    for key in key_list:
        resp = web.get('https://www.google.co.jp/search?num=100&q=' + '　'.join(key[0] + '' + add_str)
                , headers={"User-Agent": user_agent})
        resp.raise_for_status()

        # 取得したHTMLをパースする
        resp.encoding = 'utf8'  # 文字コード
        soup = bs4.BeautifulSoup(resp.text, "html.parser")

        # 検索結果の説明部分を取得
        contentList = soup.select('div > .tF2Cxc > .IsZvec span') # classの部分はdev toolsで確認する
        cnt_per_key = 0;
        for content in contentList:
            # 説明のテキスト部分のみを取得/余分な改行コードは削除する
            content_text = content.get_text().replace('\n','').replace('\r','')
            if(re.search(regPtn, content_text)):
                print([cntMusic,'T', key[0], content_text])
                
                csvwriter.writerow([cntMusic,'T', key[0], content_text])
                cntMusic += 1
                cnt_per_key +=1
            if cnt_per_key >= limit_cnt_per_key: break 
        
        time.sleep(5) # スリープ
# Out:
# [0, 'T', '人間', 'KOME 一等の義とし更に周防に一( R 形)かたまりて、して髮通を知らぬすっっしかと。 ... 屋のからになるに、と同義なれど、は今す「口は四方のかこひなりのとす、間\xa0...']
# [1, 'T', '人間', 'KOME 一等の義とし更に周防に一( R 形)かたまりて、して髮通を知らぬすっっしかと。 ... 屋のからになるに、と同義なれど、は今す「口は四方のかこひなりのとす、間\xa0...']
# [2, 'T', '人間', '在呼窑上窮向英士 11 宇間辞尋軍方註明原聲治上事剛欲之後如下諸第又利济北海秦功! ... 本故莊府長属工也在离子及於樂區治人人合書百 111 史霞之以集 1 個固味庚名成\xa0...']
# [3, 'T', '人間', '在呼窑上窮向英士 11 宇間辞尋軍方註明原聲治上事剛欲之後如下諸第又利济北海秦功! ... 本故莊府長属工也在离子及於樂區治人人合書百 111 史霞之以集 1 個固味庚名成\xa0...']
